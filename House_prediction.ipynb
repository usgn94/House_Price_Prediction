# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
train.set_index('Id')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test = pd.read_csv('test.csv')
test.set_index('Id')
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %%
train_des = train.describe()

# %%
train_des.iloc[:, 0:16]
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
train_des.iloc[:, 16:31]
# Out:
#          GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  \
# count  1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean   1515.463699      0.425342      0.057534     1.565068     0.382877
# std     525.480383      0.518911      0.238753     0.550916     0.502885
# min     334.000000      0.000000      0.000000     0.000000     0.000000
# 25%    1129.500000      0.000000      0.000000     1.000000     0.000000
# 50%    1464.000000      0.000000      0.000000     2.000000     0.000000
# 75%    1776.750000      1.000000      0.000000     2.000000     1.000000
# max    5642.000000      3.000000      2.000000     3.000000     2.000000
#
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt  \
# count   1460.000000   1460.000000   1460.000000  1460.000000  1379.000000
# mean       2.866438      1.046575      6.517808     0.613014  1978.506164
# std        0.815778      0.220338      1.625393     0.644666    24.689725
# ...

# %%
sns.jointplot(x = "PoolArea" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "ScreenPorch" , y = "SalePrice" , data = train)

# %%
train_des.iloc[:, 31:46]
# Out:
#          3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean      3.409589    15.060959     2.758904     43.489041     6.321918
# std      29.317331    55.757415    40.177307    496.123024     2.703626
# min       0.000000     0.000000     0.000000      0.000000     1.000000
# 25%       0.000000     0.000000     0.000000      0.000000     5.000000
# 50%       0.000000     0.000000     0.000000      0.000000     6.000000
# 75%       0.000000     0.000000     0.000000      0.000000     8.000000
# max     508.000000   480.000000   738.000000  15500.000000    12.000000
#
#             YrSold      SalePrice
# count  1460.000000    1460.000000
# mean   2007.815753  180921.195890
# std       1.328095   79442.502883
# min    2006.000000   34900.000000
# 25%    2007.000000  129975.000000
# 50%    2008.000000  163000.000000
# 75%    2009.000000  214000.000000
# max    2010.000000  755000.000000

# %% [raw]
# train.info()

# %% [raw]
# # Observations From Train Data
#
# ## Missing values
#
# LotFrontage      1201 non-null float64 -> 259 missing
# Alley            91 non-null object    -> 1369
# MasVnrType       1452 non-null object  -> 8
# MasVnrArea       1452 non-null float64 -> 8
# BsmtQual         1423 non-null object  -> 37
# BsmtCond         1423 non-null object  -> 37
# BsmtExposure     1422 non-null object  -> 38
# BsmtFinType1     1423 non-null object  -> 37
# BsmtFinType2     1422 non-null object  -> 38
# Electrical       1459 non-null object  -> 1
# FireplaceQu      770 non-null object   -> 692
# PoolQC           7 non-null object     -> 1453
# Fence            281 non-null object   -> 1179
# MiscFeature      54 non-null object    -> 1406
#
# ## Outlier Symptoms
# Lot Frontage
# Lot Area
# MasVnrArea
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal

# %%
train = train.drop(['Alley','PoolQC', 'Fence', 'MiscFeature', 'MasVnrArea','BsmtFinSF1','BsmtFinSF2','2ndFlrSF','LowQualFinSF','3SsnPorch','ScreenPorch','PoolArea','MiscVal'],axis = 1)
test = test.drop(['Alley','PoolQC', 'Fence', 'MiscFeature', 'MasVnrArea','BsmtFinSF1','BsmtFinSF2','2ndFlrSF','LowQualFinSF','3SsnPorch','ScreenPorch','PoolArea','MiscVal'],axis = 1)

# %%
train_des = train.describe()
train_des.iloc[:, 0:16]
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd    BsmtUnfSF  TotalBsmtSF  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   567.240411  1057.429452
# std       1.112799    30.202904     20.645407   441.866955   438.705324
# ...

# %%
train_des.iloc[:, 16:31]
# Out:
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt  \
# count   1460.000000   1460.000000   1460.000000  1460.000000  1379.000000
# mean       2.866438      1.046575      6.517808     0.613014  1978.506164
# std        0.815778      0.220338      1.625393     0.644666    24.689725
# min        0.000000      0.000000      2.000000     0.000000  1900.000000
# 25%        2.000000      1.000000      5.000000     0.000000  1961.000000
# 50%        3.000000      1.000000      6.000000     1.000000  1980.000000
# 75%        3.000000      1.000000      7.000000     1.000000  2002.000000
# max        8.000000      3.000000     14.000000     3.000000  2010.000000
#
#         GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean      1.767123   472.980137    94.244521    46.660274      21.954110
# std       0.747315   213.804841   125.338794    66.256028      61.119149
# ...

# %% [raw]
# test.info()

# %%
train_corr = train.corr()

# %%
train_corr.iloc[:, 0:16]
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# TotalBsmtSF   -0.015415   -0.238518     0.392075  0.260833     0.537808
# 1stFlrSF       0.010496   -0.251758     0.457181  0.299475     0.476224
# GrLivArea      0.008273    0.074853     0.402797  0.263116     0.593007
# ...

# %%
train_corr.iloc[:, 16:31]
# Out:
#                BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# Id                 0.037719      0.002951      0.027239   -0.019772
# MSSubClass        -0.023438      0.281721      0.040380   -0.045569
# LotFrontage        0.263170     -0.006069      0.352096    0.266639
# LotArea            0.119690     -0.017784      0.190015    0.271364
# OverallQual        0.101676     -0.183882      0.427452    0.396765
# OverallCond        0.012980     -0.087001     -0.057583   -0.023820
# YearBuilt         -0.070651     -0.174800      0.095589    0.147716
# YearRemodAdd      -0.040581     -0.149598      0.191740    0.112581
# BsmtUnfSF          0.166643      0.030086      0.250647    0.051575
# TotalBsmtSF        0.050450     -0.068901      0.285573    0.339519
# 1stFlrSF           0.127401      0.068101      0.409516    0.410531
# GrLivArea          0.521270      0.100063      0.825489    0.461679
# BsmtFullBath      -0.150673     -0.041503     -0.053275    0.137928
# ...

# %%
train = train.drop(['MSSubClass','BsmtHalfBath','BedroomAbvGr','KitchenAbvGr','EnclosedPorch','YrSold'],axis = 1)
test = test.drop(['MSSubClass','BsmtHalfBath','BedroomAbvGr','KitchenAbvGr','EnclosedPorch','YrSold'],axis = 1)

# %%
train.shape
# Out:
# (1460, 62)

# %%
test.shape
# Out:
# (1459, 61)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 62 columns):
# Id               1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# ...

# %% [raw]
# .MSZoning         1460 non-null object
# .Street           1460 non-null object
# .LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinType2     1422 non-null object
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# KitchenQual      1460 non-null object
# Functional       1460 non-null object
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageFinish     1379 non-null object
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# dtypes: float64(2), int64(21), object(39)

# %%
train['MSZoning'].head()
# Out:
# 0    RL
# 1    RL
# 2    RL
# 3    RL
# 4    RL
# Name: MSZoning, dtype: object

# %%
sns.countplot(x = "MSZoning" , data = train)

# %%
train = train.drop(['MSZoning'],axis = 1)
test = test.drop(['MSZoning'],axis = 1)

# %%
sns.countplot(x = "Street" , data = train)

# %%
train = train.drop(['Street'],axis = 1)
test = test.drop(['Street'],axis = 1)

# %%
sns.countplot(x = "LotShape" , data = train)

# %%
train = pd.get_dummies(train, prefix=['LotShape'] , columns = ['LotShape'])
test = pd.get_dummies(test, prefix=['LotShape'] , columns = ['LotShape'])

# %%
sns.countplot(x = "LandContour" , data = train)

# %%
train = train.drop(['LandContour'],axis = 1)
test = test.drop(['LandContour'],axis = 1)

# %%
sns.countplot(x = "Utilities" , data = train)

# %%
train = train.drop(['Utilities'],axis = 1)
test = test.drop(['Utilities'],axis = 1)

# %%
sns.countplot(x = "LotConfig" , data = train)

# %%
train = train.drop(['LotConfig'],axis = 1)
test = test.drop(['LotConfig'],axis = 1)

# %%
sns.countplot(x = "LandSlope" , data = train)

# %%
train = train.drop(['LandSlope'],axis = 1)
test = test.drop(['LandSlope'],axis = 1)

# %%
sns.countplot(y = "Neighborhood" , data = train)

# %%
train = train.drop(['Neighborhood'],axis = 1)
test = test.drop(['Neighborhood'],axis = 1)

# %%
sns.countplot(y = "Condition1" , data = train)

# %%
train = train.drop(['Condition1'],axis = 1)
test = test.drop(['Condition1'],axis = 1)

# %%
sns.countplot(y = "Condition2" , data = train)

# %%
train = train.drop(['Condition2'],axis = 1)
test = test.drop(['Condition2'],axis = 1)

# %%
sns.countplot(y = "BldgType" , data = train)

# %%
train = train.drop(['BldgType'],axis = 1)
test = test.drop(['BldgType'],axis = 1)

# %%
sns.countplot(y = "HouseStyle" , data = train)

# %%
train["HouseStyle"]= train["HouseStyle"].replace(['2.5Fin'], ['1Story'])

# %%
#train = train.set_index("HouseStyle")
#train = train.drop('2.5Fin', axis = 0)
#train.reset_index(inplace = True)
sns.countplot(y = "HouseStyle" , data = train)

# %%
sns.countplot(y = "HouseStyle" , data = test)

# %%
train = pd.get_dummies(train, prefix=['HouseStyle'] , columns = ['HouseStyle'])
test = pd.get_dummies(test, prefix=['HouseStyle'] , columns = ['HouseStyle'])

# %%
train.shape
# Out:
# (1460, 61)

# %%
test.shape
# Out:
# (1459, 60)

# %%
sns.countplot(y = "RoofStyle" , data = train)

# %%
train = train.drop(['RoofStyle'],axis = 1)
test = test.drop(['RoofStyle'],axis = 1)

# %%
sns.countplot(y = "RoofMatl" , data = train)

# %%
train = train.drop(['RoofMatl'],axis = 1)
test = test.drop(['RoofMatl'],axis = 1)

# %%
sns.countplot(y = "Exterior1st" , data = train)

# %%
pd.unique(train["Exterior1st"])
# Out:
# array(['VinylSd', 'MetalSd', 'Wd Sdng', 'HdBoard', 'BrkFace', 'WdShing',
#        'CemntBd', 'Plywood', 'AsbShng', 'Stucco', 'BrkComm', 'AsphShn',
#        'Stone', 'ImStucc', 'CBlock'], dtype=object)

# %%
pd.unique(test["Exterior1st"])
# Out:
# array(['VinylSd', 'Wd Sdng', 'HdBoard', 'Plywood', 'MetalSd', 'CemntBd',
#        'WdShing', 'BrkFace', 'AsbShng', 'BrkComm', 'Stucco', 'AsphShn',
#        nan, 'CBlock'], dtype=object)

# %%
train["Exterior1st"] = train["Exterior1st"].replace(['CBlock','ImStucc','Stone','AsphShn' ], ['VinylSd','VinylSd','VinylSd','VinylSd'])

# %%
sns.countplot(y = "Exterior1st" , data = train)

# %%
sns.countplot(y = "Exterior1st" , data = test)

# %%
test["Exterior1st"] = test["Exterior1st"].replace(['CBlock','AsphShn' ], ['VinylSd','VinylSd'])
test["Exterior1st"].fillna("VinylSd", inplace = True)
test["Exterior1st"].isnull().sum()
# Out:
# 0

# %%
pd.unique(test["Exterior2nd"])
# Out:
# array(['VinylSd', 'Wd Sdng', 'HdBoard', 'Plywood', 'MetalSd', 'Brk Cmn',
#        'CmentBd', 'ImStucc', 'Wd Shng', 'AsbShng', 'Stucco', 'CBlock',
#        'BrkFace', 'AsphShn', nan, 'Stone'], dtype=object)

# %%
pd.unique(train["Exterior2nd"])
# Out:
# array(['VinylSd', 'MetalSd', 'Wd Shng', 'HdBoard', 'Plywood', 'Wd Sdng',
#        'CmentBd', 'BrkFace', 'Stucco', 'AsbShng', 'Brk Cmn', 'ImStucc',
#        'AsphShn', 'Stone', 'Other', 'CBlock'], dtype=object)

# %%
train["Exterior2nd"] = train["Exterior2nd"].replace(['Other' ], ['VinylSd'])

# %%
sns.countplot(y = "Exterior2nd" , data = train)

# %%
train = pd.get_dummies(train, prefix=['Exterior2nd','Exterior1st'] , columns =['Exterior2nd','Exterior1st'])
test = pd.get_dummies(test, prefix=['Exterior2nd','Exterior1st'] , columns =['Exterior2nd','Exterior1st'])

# %%
test.shape
# Out:
# (1459, 82)

# %%
train.shape
# Out:
# (1460, 83)

# %%
sns.countplot(y = "MasVnrType" , data = train)

# %%
sns.countplot(y = "MasVnrType" , data = test)

# %%
pd.unique(test['MasVnrType'])
# Out:
# array(['None', 'BrkFace', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
test["MasVnrType"] = test["MasVnrType"].replace(['BrkCmn' ], ['BrkFace'])
test["MasVnrType"].fillna("BrkFace", inplace = True)
test["MasVnrType"].isnull().sum()
# Out:
# 0

# %%
train["MasVnrType"] = train["MasVnrType"].replace(['BrkCmn' ], ['BrkFace'])
train["MasVnrType"].fillna("BrkFace", inplace = True)
train["MasVnrType"].isnull().sum()
# Out:
# 0

# %%
sns.countplot(y = "MasVnrType" , data = test)

# %%
train = pd.get_dummies(train, prefix=['MasVnrType'] , columns =['MasVnrType'])
test = pd.get_dummies(test, prefix=['MasVnrType'] , columns =['MasVnrType'])

# %%
sns.countplot(y = "ExterQual" , data = test)

# %%
train["ExterQual"] = train["ExterQual"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])
test["ExterQual"] = test["ExterQual"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])

# %%
sns.countplot(y = "ExterCond" , data = train)

# %%
train = train.drop(['ExterCond'],axis = 1)
test = test.drop(['ExterCond'],axis = 1)

# %%
sns.countplot(y = "Foundation" , data = train)

# %%
sns.countplot(y = "Foundation" , data = test)

# %%
train["Foundation"] = train["Foundation"].replace(['Stone', 'Wood'], 'PConc')
test["Foundation"] = test["Foundation"].replace(['Stone', 'Wood'], 'CBlock')

# %%
train = pd.get_dummies(train, prefix=['Foundation'] , columns = ['Foundation'])
test = pd.get_dummies(test, prefix=['Foundation'] , columns = ['Foundation'])

# %%
train.shape
# Out:
# (1460, 87)

# %%
test.shape
# Out:
# (1459, 86)

# %%
sns.countplot(y = "BsmtQual" , data = train)

# %%
sns.countplot(y = "BsmtQual" , data = test)

# %%
train["BsmtQual"] = train["BsmtQual"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])
test["BsmtQual"] = test["BsmtQual"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])
train["BsmtQual"].fillna(3, inplace = True)
test["BsmtQual"].fillna(3, inplace = True)

# %%
sns.countplot(y = "BsmtCond" , data = train)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 87 columns):
# Id                     1460 non-null int64
# LotFrontage            1201 non-null float64
# LotArea                1460 non-null int64
# OverallQual            1460 non-null int64
# OverallCond            1460 non-null int64
# YearBuilt              1460 non-null int64
# YearRemodAdd           1460 non-null int64
# ExterQual              1460 non-null object
# BsmtQual               1460 non-null int64
# BsmtCond               1423 non-null object
# BsmtExposure           1422 non-null object
# BsmtFinType1           1423 non-null object
# BsmtFinType2           1422 non-null object
# BsmtUnfSF              1460 non-null int64
# TotalBsmtSF            1460 non-null int64
# Heating                1460 non-null object
# HeatingQC              1460 non-null object
# CentralAir             1460 non-null object
# Electrical             1459 non-null object
# ...

# %%
train = train.drop(['BsmtCond'],axis = 1)
test = test.drop(['BsmtCond'],axis = 1)

# %%
sns.countplot(y = "BsmtExposure" , data = train)

# %%
train["BsmtExposure"] = train["BsmtExposure"].replace(['Gd','Av','Mn','No','NA'], [5,4,3,2,1])
test["BsmtExposure"] = test["BsmtExposure"].replace(['Gd','Av','Mn','No','NA'], [5,4,3,2,1])

# %%
sns.countplot(y = "BsmtFinType1" , data = train)

# %%
train["BsmtFinType1"] = train["BsmtFinType1"].replace(['GLQ','ALQ','BLQ','Rec','LwQ','Unf','NA'], [7,6,5,4,3,2,1])
test["BsmtFinType1"] = test["BsmtFinType1"].replace(['GLQ','ALQ','BLQ','Rec','LwQ','Unf','NA'], [7,6,5,4,3,2,1])

# %%
sns.countplot(y = "BsmtFinType2" , data = train)

# %%
train = train.drop(['BsmtFinType2'],axis = 1)
test = test.drop(['BsmtFinType2'],axis = 1)

# %%
sns.countplot(y = "Heating" , data = train)

# %%
train = train.drop(['Heating'],axis = 1)
test = test.drop(['Heating'],axis = 1)

# %%
sns.countplot(y = "HeatingQC" , data = train)

# %%
train["HeatingQC"] = train["HeatingQC"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])
test["HeatingQC"] = test["HeatingQC"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])

# %%
sns.countplot(y = "CentralAir" , data = train)

# %%
train = train.drop(['CentralAir'],axis = 1)
test = test.drop(['CentralAir'],axis = 1)

# %%
sns.countplot(y = "Electrical" , data = train)

# %%
train = train.drop(['Electrical'],axis = 1)
test = test.drop(['Electrical'],axis = 1)

# %%
sns.countplot(y = "KitchenQual" , data = train)

# %%
train["KitchenQual"] = train["KitchenQual"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])
test["KitchenQual"] = test["KitchenQual"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])

# %%
sns.countplot(y = "Functional" , data = train)

# %%
train = train.drop(['Functional'],axis = 1)
test = test.drop(['Functional'],axis = 1)

# %%
sns.countplot(y = "KitchenQual" , data = train)

# %%
sns.countplot(y = "FireplaceQu" , data = train)

# %%
train["FireplaceQu"] = train["FireplaceQu"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])
test["FireplaceQu"] = test["FireplaceQu"].replace(['Ex','Gd','TA','Fa','Po' ], [5,4,3,2,1])

# %%
sns.countplot(y = "GarageType" , data = train)

# %%
sns.countplot(y = "GarageQual" , data = train)

# %%
train = train.drop(['GarageQual'],axis = 1)
test = test.drop(['GarageQual'],axis = 1)

# %%
sns.countplot(y = "GarageCond" , data = train)

# %%
train = train.drop(['GarageCond'],axis = 1)
test = test.drop(['GarageCond'],axis = 1)

# %%
sns.countplot(y = "PavedDrive" , data = train)

# %%
train = train.drop(['PavedDrive'],axis = 1)
test = test.drop(['PavedDrive'],axis = 1)

# %%
sns.countplot(y = "SaleType" , data = train)

# %%
train = train.drop(['SaleType'],axis = 1)
test = test.drop(['SaleType'],axis = 1)

# %%
sns.countplot(y = "SaleCondition" , data = train)

# %%
train = train.drop(['SaleCondition'],axis = 1)
test = test.drop(['SaleCondition'],axis = 1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
# Id                     1460 non-null int64
# LotFrontage            1201 non-null float64
# LotArea                1460 non-null int64
# OverallQual            1460 non-null int64
# OverallCond            1460 non-null int64
# YearBuilt              1460 non-null int64
# YearRemodAdd           1460 non-null int64
# ExterQual              1460 non-null object
# BsmtQual               1460 non-null int64
# BsmtExposure           1422 non-null object
# BsmtFinType1           1423 non-null object
# BsmtUnfSF              1460 non-null int64
# TotalBsmtSF            1460 non-null int64
# HeatingQC              1460 non-null int64
# 1stFlrSF               1460 non-null int64
# GrLivArea              1460 non-null int64
# BsmtFullBath           1460 non-null int64
# FullBath               1460 non-null int64
# HalfBath               1460 non-null int64
# ...

# %%
train = train.drop(['FireplaceQu'],axis = 1)
test = test.drop(['FireplaceQu'],axis = 1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
# Id                     1460 non-null int64
# LotFrontage            1201 non-null float64
# LotArea                1460 non-null int64
# OverallQual            1460 non-null int64
# OverallCond            1460 non-null int64
# YearBuilt              1460 non-null int64
# YearRemodAdd           1460 non-null int64
# ExterQual              1460 non-null object
# BsmtQual               1460 non-null int64
# BsmtExposure           1422 non-null object
# BsmtFinType1           1423 non-null object
# BsmtUnfSF              1460 non-null int64
# TotalBsmtSF            1460 non-null int64
# HeatingQC              1460 non-null int64
# 1stFlrSF               1460 non-null int64
# GrLivArea              1460 non-null int64
# BsmtFullBath           1460 non-null int64
# FullBath               1460 non-null int64
# HalfBath               1460 non-null int64
# ...

# %%
sns.jointplot(x = "LotFrontage" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "OverallQual" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "OverallCond" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "YearBuilt" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "YearRemodAdd" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "BsmtUnfSF" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "TotalBsmtSF" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "LotFrontage" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "1stFlrSF" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "GrLivArea" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "BsmtFullBath" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "FullBath" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "HalfBath" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "TotRmsAbvGrd" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "Fireplaces" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "GarageYrBlt" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "GarageCars" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "GarageArea" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "WoodDeckSF" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "OpenPorchSF" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "MoSold" , y = "SalePrice" , data = train)

# %%
sns.jointplot(x = "LotShape_IR1" , y = "SalePrice" , data = train)

# %%
train = train.drop(['LotShape_IR1'],axis = 1)
test = test.drop(['LotShape_IR1'],axis = 1)

# %%
sns.jointplot(x = "LotShape_IR2" , y = "SalePrice" , data = train)

# %%
train = train.drop(['LotShape_IR2'],axis = 1)
test = test.drop(['LotShape_IR2'],axis = 1)

# %%
sns.jointplot(x = "LotShape_IR3" , y = "SalePrice" , data = train)

# %%
train = train.drop(['LotShape_IR3'],axis = 1)
test = test.drop(['LotShape_IR3'],axis = 1)

# %%
sns.jointplot(x = "LotShape_Reg" , y = "SalePrice" , data = train)

# %%
train = train.drop(['LotShape_Reg'],axis = 1)
test = test.drop(['LotShape_Reg'],axis = 1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 71 columns):
# Id                     1460 non-null int64
# LotFrontage            1201 non-null float64
# LotArea                1460 non-null int64
# OverallQual            1460 non-null int64
# OverallCond            1460 non-null int64
# YearBuilt              1460 non-null int64
# YearRemodAdd           1460 non-null int64
# ExterQual              1460 non-null object
# BsmtQual               1460 non-null int64
# BsmtExposure           1422 non-null object
# BsmtFinType1           1423 non-null object
# BsmtUnfSF              1460 non-null int64
# TotalBsmtSF            1460 non-null int64
# HeatingQC              1460 non-null int64
# 1stFlrSF               1460 non-null int64
# GrLivArea              1460 non-null int64
# BsmtFullBath           1460 non-null int64
# FullBath               1460 non-null int64
# HalfBath               1460 non-null int64
# ...

# %%
X = train.drop('SalePrice', axis=1)
y = train['SalePrice']

# %%
train.shape
# Out:
# (1460, 71)

# %%
test.shape
# Out:
# (1459, 70)

# %%
sns.countplot(y = "BsmtExposure" , data = train)

# %%
sns.countplot(y = "BsmtExposure" , data = test)

# %%
train["BsmtExposure"]=train["BsmtExposure"].fillna(2)
test["BsmtExposure"]=test["BsmtExposure"].fillna(2)

# %%
sns.countplot(y = "BsmtFinType1" , data = train)

# %%
sns.countplot(y = "BsmtFinType1" , data = test)

# %%
train["BsmtFinType1"]= train["BsmtFinType1"].fillna(2)
test["BsmtFinType1"]= test["BsmtFinType1"].fillna(2)

# %%
train.shape
# Out:
# (1460, 71)

# %%
test.shape
# Out:
# (1459, 70)

# %%
train['LotFrontage'] = train['LotFrontage'].fillna(train['LotFrontage'].mean())
test['LotFrontage'] = test['LotFrontage'].fillna(train['LotFrontage'].mean())

# %%
sns.countplot(y = "GarageType" , data = train)

# %%
sns.countplot(y = "GarageType" , data = test)

# %%
train["GarageType"]= train["GarageType"].fillna("Attchd")
test["GarageType"]= test["GarageType"].fillna("Attchd")
train = pd.get_dummies(train, prefix=['GarageType'] , columns = ['GarageType'])
test = pd.get_dummies(test, prefix=['GarageType'] , columns = ['GarageType'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
# Id                     1460 non-null int64
# LotFrontage            1460 non-null float64
# LotArea                1460 non-null int64
# OverallQual            1460 non-null int64
# OverallCond            1460 non-null int64
# YearBuilt              1460 non-null int64
# YearRemodAdd           1460 non-null int64
# ExterQual              1460 non-null object
# BsmtQual               1460 non-null int64
# BsmtExposure           1460 non-null int64
# BsmtFinType1           1460 non-null int64
# BsmtUnfSF              1460 non-null int64
# TotalBsmtSF            1460 non-null int64
# HeatingQC              1460 non-null int64
# 1stFlrSF               1460 non-null int64
# GrLivArea              1460 non-null int64
# BsmtFullBath           1460 non-null int64
# FullBath               1460 non-null int64
# HalfBath               1460 non-null int64
# ...

# %%
train.loc[10:20, ['BsmtExposure']]
# Out:
#     BsmtExposure
# 10             2
# 11             2
# 12             2
# 13             4
# 14             2
# 15             2
# 16             2
# 17             2
# 18             2
# 19             2
# 20             4

# %%
test.info()

# %%
sns.countplot(y = "ExterQual" , data = train)

# %%
train["GarageYrBlt"].head()

# %%
train["GarageYrBlt"]= train["GarageYrBlt"].fillna(train["GarageYrBlt"].mean())
test["GarageYrBlt"]= test["GarageYrBlt"].fillna(test["GarageYrBlt"].mean())

# %%
sns.countplot(y = "GarageFinish" , data = train)

# %%
sns.countplot(y = "GarageFinish" , data = test)

# %%
train = pd.get_dummies(train, prefix=['GarageFinish'] , columns = ['GarageFinish'])
test = pd.get_dummies(test, prefix=['GarageFinish'] , columns = ['GarageFinish'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
# Id                     1460 non-null int64
# LotFrontage            1460 non-null float64
# LotArea                1460 non-null int64
# OverallQual            1460 non-null int64
# OverallCond            1460 non-null int64
# YearBuilt              1460 non-null int64
# YearRemodAdd           1460 non-null int64
# ExterQual              1460 non-null object
# BsmtQual               1460 non-null int64
# BsmtExposure           1460 non-null int64
# BsmtFinType1           1460 non-null int64
# BsmtUnfSF              1460 non-null int64
# TotalBsmtSF            1460 non-null int64
# HeatingQC              1460 non-null int64
# 1stFlrSF               1460 non-null int64
# GrLivArea              1460 non-null int64
# BsmtFullBath           1460 non-null int64
# FullBath               1460 non-null int64
# HalfBath               1460 non-null int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 77 columns):
# Id                     1459 non-null int64
# LotFrontage            1459 non-null float64
# LotArea                1459 non-null int64
# OverallQual            1459 non-null int64
# OverallCond            1459 non-null int64
# YearBuilt              1459 non-null int64
# YearRemodAdd           1459 non-null int64
# ExterQual              1459 non-null object
# BsmtQual               1459 non-null int64
# BsmtExposure           1459 non-null int64
# BsmtFinType1           1459 non-null int64
# BsmtUnfSF              1459 non-null float64
# TotalBsmtSF            1459 non-null float64
# HeatingQC              1459 non-null int64
# 1stFlrSF               1459 non-null int64
# GrLivArea              1459 non-null int64
# BsmtFullBath           1459 non-null float64
# FullBath               1459 non-null int64
# HalfBath               1459 non-null int64
# ...

# %%
test.info()

# %%
train['ExterQual'] = pd.DataFrame(train['ExterQual'], dtype = 'int64')
train['KitchenQual'] = pd.DataFrame(train['KitchenQual'], dtype = 'int64')

# %%
test["BsmtUnfSF"]= test["BsmtUnfSF"].fillna(test["BsmtUnfSF"].mean())
test["TotalBsmtSF"]= test["TotalBsmtSF"].fillna(test["TotalBsmtSF"].mean())
test["BsmtFullBath"]= test["BsmtFullBath"].fillna(test["BsmtFullBath"].mean())
test["GarageCars"]= test["GarageCars"].fillna(test["GarageCars"].mean())
test["GarageArea"]= test["GarageArea"].fillna(test["GarageArea"].mean())

# %%
sns.countplot(y = 'KitchenQual', data = test)

# %%
test["KitchenQual"]= test["KitchenQual"].fillna(3)

# %%
test['ExterQual'] = pd.DataFrame(test['ExterQual'], dtype = 'int64')
test['KitchenQual'] = pd.DataFrame(test['KitchenQual'], dtype = 'int64')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 77 columns):
# Id                     1459 non-null int64
# LotFrontage            1459 non-null float64
# LotArea                1459 non-null int64
# OverallQual            1459 non-null int64
# OverallCond            1459 non-null int64
# YearBuilt              1459 non-null int64
# YearRemodAdd           1459 non-null int64
# ExterQual              1459 non-null int64
# BsmtQual               1459 non-null int64
# BsmtExposure           1459 non-null int64
# BsmtFinType1           1459 non-null int64
# BsmtUnfSF              1459 non-null float64
# TotalBsmtSF            1459 non-null float64
# HeatingQC              1459 non-null int64
# 1stFlrSF               1459 non-null int64
# GrLivArea              1459 non-null int64
# BsmtFullBath           1459 non-null float64
# FullBath               1459 non-null int64
# HalfBath               1459 non-null int64
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
# Id                     1460 non-null int64
# LotFrontage            1460 non-null float64
# LotArea                1460 non-null int64
# OverallQual            1460 non-null int64
# OverallCond            1460 non-null int64
# YearBuilt              1460 non-null int64
# YearRemodAdd           1460 non-null int64
# ExterQual              1460 non-null int64
# BsmtQual               1460 non-null int64
# BsmtExposure           1460 non-null int64
# BsmtFinType1           1460 non-null int64
# BsmtUnfSF              1460 non-null int64
# TotalBsmtSF            1460 non-null int64
# HeatingQC              1460 non-null int64
# 1stFlrSF               1460 non-null int64
# GrLivArea              1460 non-null int64
# BsmtFullBath           1460 non-null int64
# FullBath               1460 non-null int64
# HalfBath               1460 non-null int64
# ...

# %%
X_train = train.drop('SalePrice', axis=1)
y = train['SalePrice']

# %%
X_test = test

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1448-8682e918ef21> in <module>
# ----> 1 y_index = X_test.iloc[:,['Id']]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(X_train,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_test = regressor.predict(X_test)

# %%
y_test
# Out:
# array([135373., 188973., 192415., ..., 192279., 122752., 254063.])

# %%
test1 = pd.read_csv('test.csv')
test1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
y_index = test1.loc[:,['Id']]
y_index = np.array(y_index, ndmin =0)
y_index = y_index.flatten()
y_index.shape
# Out:
# (1459,)

# %%
y_test = np.array(y_test, ndmin =1)
y_test.shape
# Out:
# (1459,)

# %%
Dic = {
    'Id' : y_index,
    'SalePrice' : y_test
}
Y_ans = pd.DataFrame(Dic)
Y_ans.set_index("Id")
Y_ans
# Out:
#         Id  SalePrice
# 0     1461   135373.0
# 1     1462   188973.0
# 2     1463   192415.0
# 3     1464   202795.0
# 4     1465   217775.0
# ...    ...        ...
# 1454  2915    94598.0
# 1455  2916    69544.0
# 1456  2917   192279.0
# 1457  2918   122752.0
# 1458  2919   254063.0
#
# [1459 rows x 2 columns]

# %%
Y_ans.to_csv("house_prediction.csv", index=False)
